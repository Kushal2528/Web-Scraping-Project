# %%
import pandas as pd
df=pd.read_csv('C:/Users/MyPC/OneDrive/Documents/Inbiot VS/Filtering/No 3P Dupl Remove/ACTUAL Cleaned/FINAL FOR ZONAL DISTRUBTION/Final.csv')
import numpy as np

# %%
df.head(2)
# Out:
#        AICTE ID                                  NAME  \
# 0  1-7006364088      DON BOSCO COLLEGE OF ENGINEERING
# 1  1-7006458223  INSTITUTE OF SHIPBUILDING TECHNOLOGY
#
#                             ADDRESS   DISTRICT               INSTITUTE STATE  \
# 0               DON BOSCO, FATORDA,  SOUTH GOA  Private-Self Financing   Goa
# 1  BOGDA, VASCO-DA-GAMA, GOA 403802  SOUTH GOA              Govt aided   Goa
#
#                       WEBSITE                      EMAIL
# 0  https://www.dbcegoa.ac.in/  dbcefatorda@dbcegoa.ac.in
# 1      http://www.isbt.ac.in/            isbt@isbt.ac.in

# %% [markdown]
# # Northern Zone Colleges

# %%
search=["Himachal pradesh", "Punjab", "uttarakhand","Haryana","uttar pradesh"]
north=df[df['STATE'].str.contains('|'.join(search),na=False)]
north
# Out:
#           AICTE ID                                               NAME  \
# 1969  1-7001592171            GOVERNMENT POLYTECHNIC JAMALPUR SHEKHON
# 1970  1-7001625689                   GOVERNMENT POLYTECHNIC PANCHKULA
# 1971  1-7001640222  GOVT. POLYTECHNIC CUM MULTI SKILL TRAINING CEN...
# 1972  1-7001792032                                    JKP POLYTECHNIC
# 1973  1-7001954984  B. M. INSTITUTE OF ENGINEERING AND TECHNOLOGY,...
# ...            ...                                                ...
# 2533  1-7009889209                GRAPHIC ERA DEEMED TO BE UNIVERSITY
# 2534  1-7013665624  BALWANT SINGH MUKHIYA ( BSM) COLLEGE OF ENGINE...
# 2535  1-7013372015                      PHONICS GROUP OF INSTITUTIONS
# 2536  1-7013650478            ROORKEE COLLEGE OF POLYTECHNIC ROORKEE.
# 2537  1-7003066161              INSTITUTE OF TECHNOLOGY ROORKEE (ITR)
#
#                                                 ADDRESS   DISTRICT  \
# ...

# %%
#north.to_csv('C:/Users/MyPC/OneDrive/Documents/Inbiot VS/Zonal Distribution/NorthZone.csv')

# %% [markdown]
# # Southern Zone Colleges

# %%
search=["Andhra pradesh", "karnataka", "kerala", "Tamil nadu"]
south=df[df['STATE'].str.contains('|'.join(search),na=False)]
south
# Out:
#           AICTE ID                                               NAME  \
# 924   1-7001740985                        PRAGATI ENGINEERING COLLEGE
# 925   1-7001806341           ANDHRA UNIVERSITY COLLEGE OF ENGINEERING
# 926   1-7001877027         SAGI RAMAKRISHNAM RAJU ENGINEERING COLLEGE
# 927   1-7002543651      ST. ANN'S COLLEGE OF ENGINEERING & TECHNOLOGY
# 928   1-7002575026               GOVERNMENT POLYTECHNIC, DRAKSHARAMAM
# ...            ...                                                ...
# 1848  1-7003767835                  VEDAVYASA INSTITUTE OF TECHNOLOGY
# 1849  1-7007775010              VIDYA ACADEMY OF SCIENCE & TECHNOLOGY
# 1850  1-7003815353  VIDYA ACADEMY OF SCIENCE AND TECHNOLOGY TECHNI...
# 1851  1-7007528509  VIJNAN INSTITUTE OF SCIENCE AND TECHNOLOGY (VI...
# 1852  1-7007430004             WOMEN'S POLYTECHNIC COLLEGE, ERNAKULAM
#
#                                                 ADDRESS            DISTRICT  \
# ...

# %%
#south.to_csv('C:/Users/MyPC/OneDrive/Documents/Inbiot VS/Zonal Distribution/SouthZone.csv')

# %% [markdown]
# # Eastern Zone Colleges

# %%
search=["Bihar", "Sikkim", "Arunachal", "Nagaland", "Manipur","Tripura","Meghalaya","Assam","WB","Jharkhand","Odisha","Chattishgarh"]
east=df[df['STATE'].str.contains('|'.join(search),na=False)]
east
# Out:
#          AICTE ID                                         NAME  \
# 487  1-7022096594                            C R K POLYTECHNIC
# 488  1-7014111864                   PRABHU KAILASH POLYTECHNIC
# 489  1-7014047597            MOTI BABU INSTITUTE OF TECHNOLOGY
# 490  1-7013758891       NETAJI SUBHAS INSTITUTE OF POLYTECHNIC
# 491  1-7013754900                  J.P.INSTITUTE OF TECHNOLOGY
# ..            ...                                          ...
# 919  1-7014181542                 GOVERNMENT POLYTECHNIC BERLA
# 920  1-7014183706              BILASPUR COLLEGE OF POLYTECHNIC
# 921  1-7014210050  KRUTI INSTITUTE OF TECHNOLOGY & ENGINEERING
# 922  1-7014212783                    MANSA POLYTECHNIC COLLEGE
# 923  1-7022257388           GOVT. GIRLS POLYTECHNIC, JAGDALPUR
#
#                                                ADDRESS    DISTRICT  \
# 487  MAUZA- DHANAUTI JAUNPURI/CHAKAFJAL, HAJIPUR MU...    VAISHALI
# 488                     SANATHUA MORE AURANGABAD BIHAR  AURANGABAD
# ...

# %%
#east.to_csv('C:/Users/MyPC/OneDrive/Documents/Inbiot VS/Zonal Distribution/EasternZone.csv')

# %% [markdown]
# # Western Zone Colleges

# %%
search=["Rajasthan","Madhya Pradesh","Gujarat","Maharashtra","Goa"]
west=df[df['STATE'].str.contains('|'.join(search),na=False)]
west
# Out:
#           AICTE ID                                               NAME  \
# 0     1-7006364088                   DON BOSCO COLLEGE OF ENGINEERING
# 1     1-7006458223               INSTITUTE OF SHIPBUILDING TECHNOLOGY
# 2     1-7006524807     GOA COLLEGE OF ENGINEERING (GOVERNMENT OF GOA)
# 3     1-7010374121  SHREE RAYESHWAR INSTITUTE OF ENGINEERING AND I...
# 4     1-7011315312                        HQ 2 SIGNAL TRAINING CENTRE
# ...            ...                                                ...
# 2270  1-7013302860  STANI MEMORIAL COLLEGE OF ENGINEERING & TECHNO...
# 2271  1-7013324794         MAHAVEER INSTITUTE OF TECHNOLOGY & SCIENCE
# 2272  1-7013335424                        ABUROAD POLYTECHNIC COLLEGE
# 2273  1-7015927426            SOBHASARIA GROUP OF INSTITUTIONS, SIKAR
# 2274  1-7022092448             GOVT. WOMEN POLYTECHNIC COLLEGE, AJMER
#
#                                                 ADDRESS   DISTRICT  \
# ...

# %%
#west.to_csv('C:/Users/MyPC/OneDrive/Documents/Inbiot VS/Zonal Distribution/WesternZone.csv')
